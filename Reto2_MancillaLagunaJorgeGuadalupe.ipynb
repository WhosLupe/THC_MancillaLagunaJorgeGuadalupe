# %% [markdown]
# <a href="https://colab.research.google.com/github/WhosLupe/THC_MancillaLagunaJorgeGuadalupe/blob/main/Reto2_MancillaLagunaJorgeGuadalupe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""

Reto 2#

Nombre del programa: Reto2_MancillaLagunaJorgeGuadalupe.ipynb

"""

# Para convertir unidades de longitud
def longuitud():
  # Menu 1
    print("Conversiones de longitud:")
    print("1- Metros a pies")
    print("2- Pies a metros")
    print("3- Kilómetros a millas")
  # El usuario elije que conversion usar
    num= input("Elija una opción (1, 2, 3): ")

    # Operacion de metros a pies
    if num =="1":
        m=float(input("Ingrese la longitud: "))
        ft=m*3.28084
        print(f"{m} metros equivalen a {ft}pies.")
    # Operacion de pies a metros
    elif num == "2":
        ft=float(input("Ingrese la longitud: "))
        m= ft/3.28084
        print(f"{ft} pies equivalen a {m}metros.")
    # Operacion de kilometros a millas
    elif num == "3":
        km = float(input("Ingrese la longitud: "))
        mil = km/1.60934
        print(f"{km} kilómetros equivalen a {mil}millas.")
    # Si se escribe algo que no entre en el intervalo {1, 2, 3}
    else:
        print("Entrada no valida")

# Para convertir unidades de masa
def masa():
  # Menu 2
    print("Conversiones de masa:")
    print("1- Kilogramos a libras")
    print("2- Libras a kilogramos")
    print("3- Gramos a onzas")
  # El usuario elije que conversion usar
    num =input("Elija una opción (1/2/3): ")

    # Operacion de kilos a libras
    if num=="1":
        kg= float(input("Ingrese la masa: "))
        pd = kg*2.20462
        print(f"{kg} kilogramos equivalen a {pd}libras.")
    # Operacion de libras a kilos
    elif num == "2":
        pd =float(input("Ingrese la masa: "))
        kg = pd /2.20462
        print(f"{pd} libras equivalen a {kg}kilogramos.")
    # Operacion de gramos a onzas
    elif num == "3":
        gr= float(input("Ingrese la masa: "))
        oz = gr* 0.035274
        print(f"{gr} gramos equivalen a {oz}onzas.")
    else:
        print("Entrada no valida")

# Función para convertir unidades de tiempo
def tiempo():
  # Menu 2
    print("Conversiones de tiempo:")
    print("1- Horas a segundos")
    print("2- Segundos a minutos")
    print("3- Minutos a horas")
    print("4- Minutos a milisegundos")
    print("5- Milisegundos a días")
  # El usuario elije que conversion usar
    num = input("Elija una opción (1, 2, 3, 4, 5): ")

    # Operacion de horas a segundos
    if num == "1":
        hr = float(input("Ingrese la cantidad a convertir: "))
        sec = hr * 3600
        print(f"{hr} horas equivalen a {sec} segundos.")
    # Operacion de segunos a minutos
    elif num == "2":
        sec = float(input("Ingrese la cantidad a convertir: "))
        min = sec / 60
        print(f"{sec} segundos equivalen a {min} minutos.")
    # Operacion de minutos a horas
    elif num == "3":
        min = float(input("Ingrese la cantidad a convertir: "))
        hr = min / 60
        print(f"{min} minutos equivalen a {hr} horas.")
    # Operacion de minutos a milisegundos
    elif num == "4":
        min = float(input("Ingrese la cantidad a convertir: "))
        mill = min * 60000
        print(f"{min} minutos equivalen a {mill} milisegundos.")
    # Operacion de milisegundos a dias
    elif num == "5":
        mill = float(input("Ingrese la cantidad a convertir: "))
        days = mill / 86400000
        print(f"{mill} milisegundos equivalen a {dy} días.")
    else:
        print("Entrada no válida.")

# Bucle Main
while True:
  # Menu Main
    print("Conversiones:")
    print("1- Longitud")
    print("2- Masa")
    print("3- Tiempo")
    print("4- Salir")
  # El usuario elije que conversion usar
    menu = input("Elija una opción de conversion (1, 2, 3, 4): ")

    if menu == "1":
        longuitud()
    elif menu == "2":
        masa()
    elif menu == "3":
        tiempo()
    elif menu == "4":
        print("bye :D")
        break
    else:
        print("Entrada no valida")
# Out:
# Conversiones:
# 1- Longitud
# 2- Masa
# 3- Tiempo
# 4- Salir
