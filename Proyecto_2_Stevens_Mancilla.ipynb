# %% [markdown]
# <a href="https://colab.research.google.com/github/WhosLupe/THC_MancillaLagunaJorgeGuadalupe/blob/main/Proyecto_2_Stevens_Mancilla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Link = 'https://github.com/WhosLupe/THC_proyect/blob/main/ebola_2014_2016_clean.csv'
code = '?raw=true'
url = Link+code
df = pd.read_csv(url,sep=',',index_col=1)

# %%
df.shape
# Out:
# (2484, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 29/08/2014 to 23/03/2016
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   int64
#  2   No. of confirmed deaths  1900 non-null   float64
#  3   Male Cases               2484 non-null   float64
#  4   Female Cases             2484 non-null   float64
#  5   Boys                     2484 non-null   float64
#  6   Girls                    2484 non-null   float64
#  7   Adult Male               2484 non-null   float64
#  8   Adult Female             2484 non-null   float64
#  9   Old Male                 2484 non-null   float64
#  10  Old Female               2449 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 232.9+ KB

# %%
UK=df[df['Country']=='United Kingdom']

# %%
UK
# Out:
#                    Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 02/01/2015  United Kingdom                       1                      NaN
# 05/01/2015  United Kingdom                       1                      NaN
# 06/01/2015  United Kingdom                       1                      0.0
# 07/01/2015  United Kingdom                       1                      0.0
# 08/01/2015  United Kingdom                       1                      NaN
# ...                    ...                     ...                      ...
# 17/12/2015  United Kingdom                       1                      NaN
# 22/12/2015  United Kingdom                       1                      NaN
# 23/12/2015  United Kingdom                       1                      NaN
# 29/12/2015  United Kingdom                       1                      NaN
# 23/03/2016  United Kingdom                       1                      NaN
#
# ...

# %%
UK = UK.drop('Country',axis=1)

# %%
UK.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 02/01/2015                       1                      NaN         0.6
# 05/01/2015                       1                      NaN         0.6
# 06/01/2015                       1                      0.0         0.6
# 07/01/2015                       1                      0.0         0.6
# 08/01/2015                       1                      NaN         0.6
#
#             Female Cases  Boys  Girls  Adult Male  Adult Female  Old Male  \
# Date
# 02/01/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 05/01/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 06/01/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 07/01/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 08/01/2015           0.4  0.18   0.12        0.36          0.24      0.06
#
#             Old Female
# Date
# 02/01/2015        0.04
# ...

# %%
UK.tail()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 17/12/2015                       1                      NaN         0.6
# 22/12/2015                       1                      NaN         0.6
# 23/12/2015                       1                      NaN         0.6
# 29/12/2015                       1                      NaN         0.6
# 23/03/2016                       1                      NaN         0.6
#
#             Female Cases  Boys  Girls  Adult Male  Adult Female  Old Male  \
# Date
# 17/12/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 22/12/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 23/12/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 29/12/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 23/03/2016           0.4  0.18   0.12        0.36          0.24      0.06
#
#             Old Female
# Date
# 17/12/2015        0.04
# ...

# %%
UK.shape
# Out:
# (221, 10)

# %%
UK.isnull().sum()
# Out:
# No. of confirmed cases      0
# No. of confirmed deaths    70
# Male Cases                  0
# Female Cases                0
# Boys                        0
# Girls                       0
# Adult Male                  0
# Adult Female                0
# Old Male                    0
# Old Female                 35
# dtype: int64

# %%
UK.fillna(0.0,inplace=True)

# %%
UK.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
UK['No. of confirmed deaths'].mean()
# Out:
# 4.382805429864254

# %%
UK['No. of confirmed cases'].mean()
# Out:
# 8.298642533936652

# %%
Dates=UK.index[0:-1:12]
NCC=UK['No. of confirmed cases'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
NCD=UK['No. of confirmed deaths'][0:-1:12]

# %%
plt.plot(Dates,NCC,'o-r',ms= 4,label='Infectados')#Grafica de líneas
plt.bar(Dates,NCC, color = 'red', alpha= 0.2) #Añade barras
plt.plot(Dates,NCD,'d-b',ms= 4,label='Decesos')#Grafica de líneas
plt.bar(Dates,NCD, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Avance del Ébola en el Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Periodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend()#Cuadrito de información
plt.savefig("Barras_UK.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
Hola=UK.index[0:-1:12]
NP=UK['Male Cases'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
PT=UK['Female Cases'][0:-1:12]

# %%
plt.plot(Hola,NP,'o-r',ms= 4,label='Hombres')#Grafica de líneas
plt.bar(Hola,NP, color = 'red', alpha= 0.2) #Añade barras
plt.plot(Hola,PT,'d-b',ms= 4,label='Mujeres')#Grafica de líneas
plt.bar(Hola,PT, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre casos de hombres y mujeres en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_UK.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
C=UK.index[0:-1:12]
A=UK['Adult Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
B=UK['Adult Female'][0:-1:12]

# %%
plt.plot(C,A,'o-r',ms= 4,label='Hombre Adulto')#Grafica de líneas
plt.bar(C,A, color = 'red', alpha= 0.2) #Añade barras
plt.plot(C,B,'d-b',ms= 4,label='Mujer Adulta')#Grafica de líneas
plt.bar(C,B, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres y mujeres adultos en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Periodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_UK.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
D=UK.index[0:-1:12]
F=UK['Old Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
G=UK['Old Female'][0:-1:12]

# %%
plt.plot(D,F,'o-r',ms= 4,label='Hombres Mayores')#Grafica de líneas
plt.bar(D,F, color = 'red', alpha= 0.2) #Añade barras
plt.plot(D,G,'d-b',ms= 4,label='Mujeres Mayores')#Grafica de líneas
plt.bar(D,G, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres y mujeres mayores en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_UK.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
Y=UK.index[0:-1:12]
F=UK['Old Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
H=UK['Boys'][0:-1:12]

# %%
plt.plot(Y,F,'o-r',ms= 4,label='Hombres Mayores')#Grafica de líneas
plt.bar(Y,F, color = 'red', alpha= 0.2) #Añade barras
plt.plot(Y,H,'d-b',ms= 4,label='Adolecentes Hombres')#Grafica de líneas
plt.bar(Y,H, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres mayores y adolecentes en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
Z=UK.index[0:-1:12]
G=UK['Old Female'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
E=UK['Girls'][0:-1:12]

# %%
plt.plot(Z,G,'o-r',ms= 4,label='Mujeres Mayores')#Grafica de líneas
plt.bar(Z,G, color = 'red', alpha= 0.2) #Añade barras
plt.plot(Z,E,'d-b',ms= 4,label='Adolecentes Mujeres')#Grafica de líneas
plt.bar(Z,E, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de mujeres mayores y adolecentes mujeres en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_UK.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
O=UK.index[0:-1:12]
A=UK['Adult Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
G=UK['Old Female'][0:-1:12]

# %%
plt.plot(O,A,'o-r',ms= 4,label='Hombres Adultos')#Grafica de líneas
plt.bar(O,A, color = 'red', alpha= 0.2) #Añade barras
plt.plot(O,G,'d-b',ms= 4,label='Mujeres Mayores')#Grafica de líneas
plt.bar(O,G, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres adultos y mujeres mayores en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_UK.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
U=UK.index[0:-1:12]
B=UK['Adult Female'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
H=UK['Boys'][0:-1:12]

# %%
plt.plot(U,B,'o-r',ms= 4,label='Mujeres Adultas')#Grafica de líneas
plt.bar(U,B, color = 'red', alpha= 0.2) #Añade barras
plt.plot(U,H,'d-b',ms= 4,label='Adolecentes Hombres')#Grafica de líneas
plt.bar(U,H, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de mujeres adultas y adolecentes hombres en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_UK.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
[df['Country']=='Italy']
# Out:
# [Date
#  29/08/2014    False
#  29/08/2014    False
#  29/08/2014    False
#  29/08/2014    False
#  05/09/2014    False
#                ...
#  23/03/2016    False
#  23/03/2016     True
#  23/03/2016    False
#  23/03/2016    False
#  23/03/2016    False
#  Name: Country, Length: 2484, dtype: bool]

# %%
SL=df[df['Country']=='Italy']

# %%
SL
# Out:
#            Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 14/05/2015   Italy                       1                      0.0
# 15/05/2015   Italy                       1                      0.0
# 18/05/2015   Italy                       1                      0.0
# 19/05/2015   Italy                       1                      0.0
# 20/05/2015   Italy                       1                      0.0
# ...            ...                     ...                      ...
# 17/12/2015   Italy                       4                      1.0
# 22/12/2015   Italy                       4                      1.0
# 23/12/2015   Italy                       1                      NaN
# 29/12/2015   Italy                       1                      NaN
# 23/03/2016   Italy                       1                      NaN
#
#             Male Cases  Female Cases  Boys  Girls  Adult Male  Adult Female  \
# Date
# ...

# %%
SL = SL.drop('Country',axis=1)

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 14/05/2015                       1                      0.0         0.6
# 15/05/2015                       1                      0.0         0.6
# 18/05/2015                       1                      0.0         0.6
# 19/05/2015                       1                      0.0         0.6
# 20/05/2015                       1                      0.0         0.6
#
#             Female Cases  Boys  Girls  Adult Male  Adult Female  Old Male  \
# Date
# 14/05/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 15/05/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 18/05/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 19/05/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 20/05/2015           0.4  0.18   0.12        0.36          0.24      0.06
#
#             Old Female
# Date
# 14/05/2015        0.04
# ...

# %%
SL.tail()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 17/12/2015                       4                      1.0         2.4
# 22/12/2015                       4                      1.0         2.4
# 23/12/2015                       1                      NaN         0.6
# 29/12/2015                       1                      NaN         0.6
# 23/03/2016                       1                      NaN         0.6
#
#             Female Cases  Boys  Girls  Adult Male  Adult Female  Old Male  \
# Date
# 17/12/2015           1.6  0.72   0.48        1.44          0.96      0.24
# 22/12/2015           1.6  0.72   0.48        1.44          0.96      0.24
# 23/12/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 29/12/2015           0.4  0.18   0.12        0.36          0.24      0.06
# 23/03/2016           0.4  0.18   0.12        0.36          0.24      0.06
#
#             Old Female
# Date
# 17/12/2015        0.16
# ...

# %%
SL.shape
# Out:
# (141, 10)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases      0
# No. of confirmed deaths    38
# Male Cases                  0
# Female Cases                0
# Boys                        0
# Girls                       0
# Adult Male                  0
# Adult Female                0
# Old Male                    0
# Old Female                  0
# dtype: int64

# %%
SL.fillna(0.0,inplace=True)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
SL['No. of confirmed deaths'].mean()
# Out:
# 3.6666666666666665

# %%
SL['No. of confirmed cases'].mean()
# Out:
# 12.567375886524824

# %%
Dates=SL.index[0:-1:12]
NCC=SL['No. of confirmed cases'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
NCD=SL['No. of confirmed deaths'][0:-1:12]

# %%
plt.plot(Dates,NCC,'o--m',ms= 4,label='Infectados')#Grafica de líneas
plt.bar(Dates,NCC, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(Dates,NCD,'d--b',ms= 4,label='Decesos')#Grafica de líneas
plt.bar(Dates,NCD, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Avance del Ébola en Italia')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
Hola=SL.index[0:-1:12]
NP=SL['Male Cases'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
PT=SL['Female Cases'][0:-1:12]

# %%
plt.plot(Hola,NP,'o--m',ms= 4,label='Hombres')#Grafica de líneas
plt.bar(Hola,NP, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(Hola,PT,'d--b',ms= 4,label='Mujeres')#Grafica de líneas
plt.bar(Hola,PT, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de Hombre y Mujeres en Italia')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
Holaa=SL.index[0:-1:12]
H=SL['Boys'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
E=SL['Girls'][0:-1:12]

# %%
plt.plot(Holaa,H,'o--m',ms= 4,label='Adolecentes Hombres')#Grafica de líneas
plt.bar(Holaa,H, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(Holaa,E,'d--b',ms= 4,label='Adolecentes Mujeres')#Grafica de líneas
plt.bar(Holaa,E, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de adolecentes hombres y adolecentes mujeres en Italia')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
C=SL.index[0:-1:12]
A=SL['Adult Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
B=SL['Adult Female'][0:-1:12]

# %%
plt.plot(C,A,'o--m',ms= 4,label='Hombres Adultos')#Grafica de líneas
plt.bar(C,A, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(C,B,'d--b',ms= 4,label='Mujeres Adultas')#Grafica de líneas
plt.bar(C,B, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres adultos y mujeres adultas en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
D=SL.index[0:-1:12]
F=SL['Old Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
G=SL['Old Female'][0:-1:12]

# %%
plt.plot(D,F,'o--m',ms= 4,label='Hombres Mayores')#Grafica de líneas
plt.bar(D,F, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(D,G,'d--b',ms= 4,label='Mujeres Mayores')#Grafica de líneas
plt.bar(D,G, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres mayores y mujeres mayores en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
Y=SL.index[0:-1:12]
F=SL['Old Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
H=SL['Boys'][0:-1:12]

# %%
plt.plot(Y,F,'o--m',ms= 4,label='Hombres Mayores')#Grafica de líneas
plt.bar(Y,F, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(Y,H,'d--b',ms= 4,label='Adolecentes Hombres')#Grafica de líneas
plt.bar(Y,H, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres adultos y adolecentes hombres en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
Z=SL.index[0:-1:12]
G=SL['Old Female'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
E=SL['Girls'][0:-1:12]

# %%
plt.plot(Z,G,'o--m',ms= 4,label='Mujeres Mayores')#Grafica de líneas
plt.bar(Z,G, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(Z,E,'d--b',ms= 4,label='Adolecentes Mujeres')#Grafica de líneas
plt.bar(Z,E, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de mujeres mayores y adolecentes hombres en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
O=SL.index[0:-1:12]
A=SL['Adult Male'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
G=SL['Old Female'][0:-1:12]

# %%
plt.plot(O,A,'o--m',ms= 4,label='Hombres Adultos')#Grafica de líneas
plt.bar(O,A, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(O,G,'d--b',ms= 4,label='Mujeres Mayores ')#Grafica de líneas
plt.bar(O,G, color = 'blue', alpha= 0.2) #Añade b arras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de hombres adultos y mujeres mayores en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
U=SL.index[0:-1:12]
B=SL['Adult Female'][0:-1:12] #CREA UNA VARIABLE PARA CADA CASO
H=SL['Boys'][0:-1:12]

# %%
plt.plot(U,B,'o--m',ms= 4,label='Mujeres Adultas')#Grafica de líneas
plt.bar(U,B, color = 'magenta', alpha= 0.2) #Añade barras
plt.plot(U,H,'d--b',ms= 4,label='Adolecentes Hombres')#Grafica de líneas
plt.bar(U,H, color = 'blue', alpha= 0.2) #Añade barras
plt.grid()#Agrega la grilla
plt.title('Comparacion entre Casos de mujeres adultas y adolecentes hombres en Reino Unido')#Título de la gráfica
plt.ylabel('Casos Confirmados')#Título de los datos del eje y
plt.xlabel('Perdiodo de tiempo')#Título de los datos del eje x
plt.xticks(rotation=90,fontsize=8) #Acomodamos las variables del eje x
plt.legend() #Cuadrito de información
plt.savefig("Barras_SL.png", dpi = 300,format = 'png')#Línea para habilitar el guardar la gráfica
plt.show()#Línea para mostrar la gráfica

# %%
PIvsD = 100*SL['No. of confirmed deaths']/SL['No. of confirmed cases']
PIvsD
# Out:
# Date
# 14/05/2015     0.0
# 15/05/2015     0.0
# 18/05/2015     0.0
# 19/05/2015     0.0
# 20/05/2015     0.0
#               ...
# 17/12/2015    25.0
# 22/12/2015    25.0
# 23/12/2015     0.0
# 29/12/2015     0.0
# 23/03/2016     0.0
# Length: 141, dtype: float64

# %%
SL['PIvsD']=PIvsD

# %%
recuperados = ((100-PIvsD)/100)*SL['No. of confirmed cases']
SL['recuperados'] = recuperados

# %%
SL['PR'] = (100-PIvsD)

# %%
PIvsD_mean = SL['PIvsD'].mean()
PR_mean = SL['PR'].mean()
porcentajes = [PIvsD_mean,PR_mean]
etiquetas = ['Descesos','Recuperaciones']

# %%
plt.pie(porcentajes,labels=etiquetas,autopct='%0.1f %%', colors=['gray','pink'])#Colores del gráfico
plt.axis("equal")
plt.title('Porcentaje entre recuperados vs decesos en Italia')
plt.savefig("Pastel_PIvsD_PR", dpi = 300,format = 'png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
PIvsD2 = 100*UK['No. of confirmed deaths']/UK['No. of confirmed cases']
PIvsD2
# Out:
# Date
# 02/01/2015    0.0
# 05/01/2015    0.0
# 06/01/2015    0.0
# 07/01/2015    0.0
# 08/01/2015    0.0
#              ...
# 17/12/2015    0.0
# 22/12/2015    0.0
# 23/12/2015    0.0
# 29/12/2015    0.0
# 23/03/2016    0.0
# Length: 221, dtype: float64

# %%
UK['PIvsD2']=PIvsD2

# %%
recuperados = ((100-PIvsD2)/100)*UK['No. of confirmed cases']
UK['recuperados'] = recuperados

# %%
UK['PR'] = (100-PIvsD2)

# %%
PIvsD2_mean = UK['PIvsD2'].mean()
PR_mean = UK['PR'].mean()
porcentajes = [PIvsD_mean,PR_mean]
etiquetas = ['Descesos','Recuperaciones']

# %%
plt.pie(porcentajes,labels=etiquetas,autopct='%0.1f %%', colors=['gray','green'])#Colores del gráfico
plt.axis("equal")
plt.title('Porcentaje entre recuperados vs decesos en Reino Unido')#Título sd
plt.savefig("Pastel_PIvsD2_PR", dpi = 300,format = 'png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
